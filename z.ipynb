# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Marks_Data.csv")

# %%
# Mean percentage of Roma
m = df.loc[df['Student_Name'] == 'Roma',
        ['Maths', 'Science', 'English']].mean(axis=1).iloc[0]
print("Percentage:", m, "%")
# Out:
# Percentage: 26.333333333333332 %

# %%
if m < 45:
    print("Fail")
else:
    print("Pass")

# Total & Rank
df['Total'] = df[['Maths','Science','English']].sum(axis=1)
df['Rank'] = df['Total'].rank(ascending=False)
# Out:
# Fail

# %%
print(df)

# Plot
plt.figure()
df.plot(x='Student_Name', y=['Maths','Science','English'], kind='bar')
plt.show()
# Out:
#   Student_Name  Maths  Science  English  Total  Rank
# 0          Lex     70       45       67    182   2.0
# 1          Raj     98       78       76    252   1.0
# 2         Roma     30       29       20     79   3.0
